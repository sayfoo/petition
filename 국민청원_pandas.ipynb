# %%
from bs4 import BeautifulSoup
from urllib.request import urlopen
from urllib.parse import quote_plus
from selenium import webdriver
import pandas as pd

driver = webdriver.Chrome()

end_page = 31 # 2019년 12월 3일 오후 6시 기준
index = 0 
columns = ["번호", "분류", "제목", "청원 종료일", "참여인원"]
df_petition = pd.DataFrame(columns=columns)

for page in range(1, end_page+1):
    # 국민청원 url
    url = f"https://www1.president.go.kr/petitions/?c=0&only=1&page={page}&order=1"
    driver.get(url)
    driver.implicitly_wait(3)

    html = driver.page_source
    soup = BeautifulSoup(html, "html.parser")
    petition_table = soup.find("ul", class_="petition_list")
    
    for one_column in petition_table.find_all("div", class_="bl_wrap"):
        number = one_column.find("div", class_="bl_no").text.replace("번호 ", "")
        category = one_column.find("div", class_="bl_category ccategory cs wv_category").text.replace("분류 ", "")
        subject = one_column.find("div", class_="bl_subject").text.replace("제목 ", "")
        end_date = one_column.find("div", class_="bl_date light").text.replace("청원 종료일 ", "")
        agree = one_column.find("div", class_="bl_agree cs").text.replace("참여인원 ", "")
        
        df_petition.loc[index, "번호"] = number
        df_petition.loc[index, "분류"] = category
        df_petition.loc[index, "제목"] = subject
        df_petition.loc[index, "청원 종료일"] = end_date
        df_petition.loc[index, "참여인원"] = agree
        index += 1

        print("-"*80)
        print(f"{number}\n{category}\n{subject}\n{end_date}\n{agree}")
        
driver.close()
# Out:
# --------------------------------------------------------------------------------
# 463
# 기타
# 불공정한보도를한 언론의 제재시스템
# 2020-01-02
# 135명
# --------------------------------------------------------------------------------
# 462
# 교통/건축/국토
# 부동산 다운계약, 다운거래의 악습을 끊어주세요.
# 2020-01-02
# 105명
# --------------------------------------------------------------------------------
# 461
# 육아/교육
# 교육부의 지침에 따른 고등학교 윤리교과서의 "인민주권"표기에 대해 수정을 요구합니다.
# 2020-01-02
# 137명
# --------------------------------------------------------------------------------
# 460
# 육아/교육
# 성폭력을 두둔한 박능후 보건복지부 장관의 사퇴를 촉구합니다.
# 2020-01-02
# 6,291명
# --------------------------------------------------------------------------------
# 459
# 문화/예술/체육/언론
# 성남 어린이집 성폭행 사건 가해자 아버지가 소속된 **** **팀 해산을 요청 합니다.
# 2020-01-02
# 1,706명
# --------------------------------------------------------------------------------
# 458
# 육아/교육
# 사립 유치원 교사들도 국가호봉 지급해 주세요.
# 2020-01-02
# 114명
# --------------------------------------------------------------------------------
# 457
# 인권/성평등
# 피해자 중심적인 보도와 법률집행의 폐단을 없애주세요
# 2020-01-02
# 132명
# --------------------------------------------------------------------------------
# 456
# 보건복지
# BRCA 유전자 변이가 없는 91%의 난소암 환자들도 신약을 복용하게 해주세요.
# 2020-01-02
# 498명
# --------------------------------------------------------------------------------
# 455
# 정치개혁
# 직무유기 국회의원 처벌법 제정을 청원합니다
# 2020-01-02
# 340명
# --------------------------------------------------------------------------------
# 454
# 안전/환경
# 업주들만 처벌받는 미성년자의 음주, 흡연
# 2020-01-02
# 259명
# --------------------------------------------------------------------------------
# 453
# 육아/교육
# 서울 중구청장의 졸속행정으로 부터 중구 아이들을 살려주십시오!!!
# 2020-01-02
# 316명
# --------------------------------------------------------------------------------
# 452
# 교통/건축/국토
# 은평뉴타운내 주민의견을 무시한 여명학교 신설/이전 추진을 막아주세요
# 2020-01-02
# 116명
# --------------------------------------------------------------------------------
# 451
# 육아/교육
# 부모들이 안심하고 자녀를 보낼 수 있는 유치원을 만들어주세요.
# 2020-01-02
# 281명
# --------------------------------------------------------------------------------
# 450
# 일자리
# 150여명의 직원이 실직자가 되었습니다
# 2020-01-02
# 129명
# --------------------------------------------------------------------------------
# 449
# 육아/교육
# 청소년을 착취하며 성장한 1:1 영어 교육업체 ******-에 대한 감사 및 사법조치가 시급합니다. (온오프라인 병합 인터넷강의 학원)
# 2020-01-02
# 125명
# --------------------------------------------------------------------------------
# 448
# 교통/건축/국토
# 부실공사 **건설과 부실을 관가하는 시행사 lh공사를 고발합니다.
# 2020-01-02
# 139명
# --------------------------------------------------------------------------------
# 447
# 육아/교육
# 고교교사가 제 자녀의 학생부에 악의적 허위내용을 기재하여 수시전형에서 모두 탈락하게 되었습니다.
# 2020-01-01
# 284명
# --------------------------------------------------------------------------------
# 446
# 정치개혁
# 국회에서는 법안으로 인질 잡고 협상하는 카드로 사용하지 말아 주시기 바랍니다.
# 2020-01-01
# 301명
# --------------------------------------------------------------------------------
# 445
# 정치개혁
# 국회의원 임기 제한제 도입을 촉구합니다
# 2020-01-01
# 369명
# --------------------------------------------------------------------------------
# 444
# 육아/교육
# 처음학교로 시스템 개선이 필요합니다.
# 2020-01-01
# 247명
# --------------------------------------------------------------------------------
# 443
# 보건복지
# 중증환자 개인 간병비 너무 힘들어요.
# 2020-01-01
# 418명
# --------------------------------------------------------------------------------
# 442
# 행정
# 언제까지 재판을 해야 하는가요?.... 제발 도와주세요
# 2020-01-01
# 317명
# --------------------------------------------------------------------------------
# 441
# 인권/성평등
# **당 지역 위원장의 군의원에 대한 성추행 사건에 대한 청원
# 2020-01-01
# 4,883명
# --------------------------------------------------------------------------------
# 440
# 육아/교육
# 수능성적표 부정확인한 인원 전원 0점 처리 바랍니다.
# 2020-01-01
# 780명
# --------------------------------------------------------------------------------
# 439
# 반려동물
# 오늘도 자살충동을 느끼며 이글을 씁니다! 개고양이 식용종식해주세요!!
# 2020-01-01
# 603명
# --------------------------------------------------------------------------------
# 438
# 안전/환경
# 천안시 광덕면 원덕리 소각장건립을 막아주세요
# 2020-01-01
# 403명
# --------------------------------------------------------------------------------
# 437
# 교통/건축/국토
# 창원 **터널 5중 추돌사고, 저희 할아버지의 죽음과 같은 사고가 다시는 일어나지 않게 해주세요.
# 2020-01-01
# 3,066명
# --------------------------------------------------------------------------------
# 436
# 안전/환경
# 보이스 피싱 피해자입니다.
# 2020-01-01
# 291명
# --------------------------------------------------------------------------------
# 435
# 안전/환경
# 수도권매립지 2025년 폐쇄를 요청합니다.
# 2020-01-01
# 1,582명
# --------------------------------------------------------------------------------
# 434
# 안전/환경
# 친부에 의한 아동 성폭력 피해자입니다.
# 2020-01-01
# 10,756명
# --------------------------------------------------------------------------------
# 418
# 보건복지
# 인공관절 수술후 식물인간으로계시다가 돌아가셨습니다
# 2020-01-01
# 189명
# --------------------------------------------------------------------------------
# 417
# 육아/교육
# **고등학교의 횡포를 멈춰주세요!!
# 2020-01-01
# 412명
# --------------------------------------------------------------------------------
# 416
# 육아/교육
# 어린이 보육시설 cctv 상시 공개 의무화
# 2020-01-01
# 1,103명
# --------------------------------------------------------------------------------
# 415
# 기타
# 살인마들 다단계코인 사기범
# 2020-01-01
# 214명
# --------------------------------------------------------------------------------
# 414
# 정치개혁
# 국회의원 세비 인상 반대합니다
# 2020-01-01
# 582명
# --------------------------------------------------------------------------------
# 413
# 보건복지
# 불법도박의 피해가 점차 심각해지고 있습니다 도와주세요!!
# 2020-01-01
# 231명
# --------------------------------------------------------------------------------
# 412
# 안전/환경
# 실효성 없는 5등급차 운행금지, 2부제 강제시행을 철회해주십시오.
# 2019-12-29
# 1,770명
# --------------------------------------------------------------------------------
# 411
# 정치개혁
# 박근혜 탄핵정국 계엄령 내란음모 통진당처럼 똑같이 정당해산 하라!!@
# 2019-12-29
# 1,894명
# --------------------------------------------------------------------------------
# 410
# 정치개혁
# 나경원 자유한국당 의원의 공직선거법 위반과 관련하여  철저한 수사를 촉구합니다.
# 2019-12-29
# 29,374명
# --------------------------------------------------------------------------------
# 409
# 정치개혁
# 자유한국당 해체(해산)를 촉구합니다.
# 2019-12-29
# 57,377명
# --------------------------------------------------------------------------------
# 408
# 정치개혁
# *** ** 윤석열 검찰청장 즉시 체포 파면 특검수사요구
# 2019-12-29
# 2,854명
# --------------------------------------------------------------------------------
# 407
# 경제민주화
# ‘이재용 부회장’도 ‘임원’도 반드시 구속되어야 합니다.
# 2019-12-29
# 1,586명
# --------------------------------------------------------------------------------
# 406
# 정치개혁
# 공수처, 패스트트랙, 연동형 비례대표제 결사 반대합니다.
# 2019-12-29
# 17,765명
# --------------------------------------------------------------------------------
# 405
# 육아/교육
# 국가자격증 미용학원 법 개정 및 감사가 시급합니다.
# 2019-12-29
# 247명
# --------------------------------------------------------------------------------
# 404
# 교통/건축/국토
# 가두리 부동산 개인정보 공유, 담합 등 불법행위 조사해 주세요
# 2019-12-29
# 771명
# --------------------------------------------------------------------------------
# 388
# 저출산/고령화대책
# 저출산 시대의 다자녀 가구 지원
# 2019-12-29
# 389명
# --------------------------------------------------------------------------------
# 387
# 일자리
# 근로기준법 일부 개정 (휴게시간의 상한) 청원합니다.
# 2019-12-28
# 1,019명
# --------------------------------------------------------------------------------
# 386
# 기타
# 필리핀 관광객 입국비자 서류간소화및 비자발급기간 단축 과 더불어 상호무비자 협정체결
# 2019-12-28
# 249명
# --------------------------------------------------------------------------------
# 385
# 육아/교육
# 저출산을 걱정하며 왜 학폭위 처벌은 솜방망이인가요?
# 2019-12-28
# 537명
# --------------------------------------------------------------------------------
# 384
# 외교/통일/국방
# 강제징용 피해자 외면하는 "문희상 안" 백지화에 힘을 보태주십시오
# 2019-12-28
# 12,660명
# --------------------------------------------------------------------------------
# 383
# 정치개혁
# 공수처 신설 법안을 국회에서 대상 확대 발의하여 국회 통과 요청및 양승태 공소장 공범 권순일 대법관을 서울 중앙 지검 특별 공판팀에 제출한 최종 의견서등을 보고 구속 수사 하라!
# 2019-12-28
# 802명
# --------------------------------------------------------------------------------
# 382
# 안전/환경
# 충북 충주시 **고등학교의 한 학생에 의한 장기간의 심각한 학교폭력을 축소 은폐하고자 불법 공모한 지역사회 공 기관(충북교육청, **경찰서, 학교)을 고발합니다.
# 2019-12-28
# 500명
# --------------------------------------------------------------------------------
# 381
# 행정
# 지방 중소기업을 죽이기 위해 대기업 **와 **시청의 유착을 고발합니다.
# 2019-12-28
# 844명
# --------------------------------------------------------------------------------
# 380
# 행정
# 일하지 않는 공무원을 처벌하여 주세요(근로감독관 소극행정,갑질)
# 2019-12-28
# 420명
# --------------------------------------------------------------------------------
# 379
# 안전/환경
# 중학교 배정 및 통학로 안전 확보
# 2019-12-28
# 188명
# --------------------------------------------------------------------------------
# 378
# 인권/성평등
# 성관계영상협박여부에 중점을둔성범죄가중처, 반대성별 남성, 여성법조인의 불필요한 영상시청요구 막아주세요.
# 2019-12-28
# 2,055명
# --------------------------------------------------------------------------------
# 377
# 육아/교육
# 제30회 공인중개사시험 이의신청 문제
# 2019-12-28
# 400명
# --------------------------------------------------------------------------------
# 376
# 반려동물
# 반려동물 1000만시대, 반려동물공장을 없애주세요
# 2019-12-28
# 1,256명
# --------------------------------------------------------------------------------
# 375
# 육아/교육
# 20학년도 수능 **고등학교 사태
# 2019-12-28
# 608명
# --------------------------------------------------------------------------------
# 374
# 정치개혁
# 2020년 4월 15일 선거 총선에 (전자개표ㆍ사전투표) 폐지 VS 수개표 진행 청원
# 2019-12-28
# 2,766명
# --------------------------------------------------------------------------------
# 373
# 보건복지
# 대한민국 하청 노동자 세금체납
# 2019-12-28
# 499명
# --------------------------------------------------------------------------------
# 372
# 교통/건축/국토
# 국가에 강제수용되는 토지에 관한 양도세 100% 감면
# 2019-12-28
# 988명
# --------------------------------------------------------------------------------
# 371
# 교통/건축/국토
# 횡단보도 사망사고 가해자를 구속수사 해주세요.
# 2019-12-28
# 421명
# --------------------------------------------------------------------------------
# 370
# 안전/환경
# 산업용 보일러 안전관리자 선임 자격 하향평준화에 대해 반대합니다.
# 2019-12-28
# 398명
# --------------------------------------------------------------------------------
# 369
# 교통/건축/국토
# 건설사의 행포를 막아주세요
# 2019-12-28
# 360명
# --------------------------------------------------------------------------------
# 368
# 인권/성평등
# 아버지란 이름의 성폭력 가해자를 벌해주십시오
# 2019-12-28
# 83,202명
# --------------------------------------------------------------------------------
# 367
# 보건복지
# 재 동생의 억울한 죽음을 발켜 주세요 (간곡히 부탁드립니다)
# 2019-12-28
# 413명
# --------------------------------------------------------------------------------
# 366
# 육아/교육
# 센서 경보음으로 인해서 수능 수학시험을 망쳤습니다
# 2019-12-27
# 1,611명
# --------------------------------------------------------------------------------
# 365
# 보건복지
# 삶이 파괴되었습니다. "의료사고" 전담 "국가의 감정기관"을 설립해 주세요.
# 2019-12-27
# 387명
# --------------------------------------------------------------------------------
# 364
# 문화/예술/체육/언론
# 음원 차트를 조작하는 사재기를 막아주세요
# 2019-12-27
# 6,124명
# --------------------------------------------------------------------------------
# 363
# 안전/환경
# 미세먼지 주범인 건설현장 불량 안전망의 KS 인증제품 사용 의무화를 청원합니다
# 2019-12-27
# 182명
# --------------------------------------------------------------------------------
# 362
# 반려동물
# 반려동물 입양 절차 강화! 무책임하게 반려동물을 입양하지 못하게 해주세요
# 2019-12-27
# 685명
# --------------------------------------------------------------------------------
# 361
# 교통/건축/국토
# 시각장애인도 버스를 탈 수 있게 해주세요.
# 2019-12-27
# 3,119명
# --------------------------------------------------------------------------------
# 360
# 육아/교육
# ‘학교 주자창 개방법’에 반대한다!
# 2019-12-27
# 6,925명
# --------------------------------------------------------------------------------
# 359
# 저출산/고령화대책
# 획기적인 출산지원금을 통해 출산율을 높여 주세요
# 2019-12-27
# 197명
# --------------------------------------------------------------------------------
# 283
# 행정
# 전과88범이  때려도 맞고 있어야 되나요?
# 2019-12-22
# 8,853명
# --------------------------------------------------------------------------------
# 282
# 일자리
# 장애인주제에 아무거나하지 장애인 고용공단 **지사
# 2019-12-22
# 714명
# --------------------------------------------------------------------------------
# 281
# 기타
# 대기업 보험사의 횡포를 막아주세요.
# 2019-12-22
# 196명
# --------------------------------------------------------------------------------
# 280
# 기타
# **렌트카 회사의 횡포를 고발합니다.
# 2019-12-22
# 294명
# --------------------------------------------------------------------------------
# 279
# 육아/교육
# 원장담임겸임제 폐지
# 2019-12-21
# 1,504명
# --------------------------------------------------------------------------------
# 278
# 인권/성평등
# 대전지법 **부 검사와 판사의 불법감금
# 2019-12-21
# 623명
# --------------------------------------------------------------------------------
# 277
# 보건복지
# 65세이상 장애인활동지원 중단을 반대합니다
# 2019-12-21
# 3,349명
# --------------------------------------------------------------------------------
# 276
# 보건복지
# 현실에 맞는 장애인 지원 및 법과 제도 수정을 요청합니다.
# 2019-12-21
# 181명
# --------------------------------------------------------------------------------
# 275
# 기타
# 우리의 억울함을 풀어주세요
# 2019-12-21
# 252명
# --------------------------------------------------------------------------------
# 274
# 보건복지
# 피해자가 의료사고 입증?   의료사고 관련 법령개정을 촉구합니다
# 2019-12-21
# 1,654명
# --------------------------------------------------------------------------------
# 273
# 육아/교육
# 수험생의 노력이 헛되지 않도록 수능 4교시 운영방식을 개선해주세요.
# 2019-12-21
# 4,148명
# --------------------------------------------------------------------------------
# 272
# 기타
# A사 145만대 자동세척건조기 환불진행 해주세요
# 2019-12-21
# 7,220명
# --------------------------------------------------------------------------------
# 271
# 일자리
# 가업을 이어갈수 있도록
# 2019-12-20
# 184명
# --------------------------------------------------------------------------------
# 270
# 문화/예술/체육/언론
# *** 코리아의***, *** 전 *** 대표, *** 현 *** 감독의 징계에 대한 재조사가 필요합니다.
# 2019-12-20
# 205,672명
# --------------------------------------------------------------------------------
# 269
# 문화/예술/체육/언론
# *** 코리아의 적폐 운영, 국회에서 제대로 조사해 주셨으면 합니다.
# 2019-12-20
# 3,112명
# --------------------------------------------------------------------------------
# 238
# 인권/성평등
# 근무시간에 해서는 안될 행동을 하는 고위직 공무원의 민원인 희롱 사건을 고발합니다-직위파면을 청원합니다.
# 2019-12-18
# 833명
# --------------------------------------------------------------------------------
# 237
# 안전/환경
# 우리 생명과 직결되는 국민안전 분야에 대한 엄격한 적폐청산 요구합니다.
# 2019-12-18
# 237명
# --------------------------------------------------------------------------------
# 236
# 일자리
# 고졸 9급 공무원 채용이 전국 시도별로 고르게 확대 되었으면 합니다.
# 2019-12-18
# 325명
# --------------------------------------------------------------------------------
# 235
# 반려동물
# 동물보호법 강화해주십시오
# 2019-12-18
# 3,908명
# --------------------------------------------------------------------------------
# 234
# 행정
# 윤석렬 검찰총장을 직권남용 및 공무집행방해 죄로 처벌해주세요.
# 2019-12-18
# 1,444명
# --------------------------------------------------------------------------------
# 233
# 정치개혁
# 박근혜 석방을 반대 합니다
# 2019-12-18
# 3,083명
# --------------------------------------------------------------------------------
# 232
# 정치개혁
# 부산광역시는 부산가치더[+]랩 사업을 일방적인 사업주체를 선정 및 졸속 행정에 대해 항의합니다.
# 2019-12-18
# 275명
# --------------------------------------------------------------------------------
# 231
# 안전/환경
# "내고향 농촌마을이 울고 있어요. 마을을 끼고 있는 주변 토지에 태양광발전시설을 하지 말아 주세요"
# 2019-12-18
# 239명
# --------------------------------------------------------------------------------
# 230
# 인권/성평등
# ***재벌 *** 집 앞에서 1인 시위하다 전직 경찰에게 전치 4주 폭행당했는데 검찰 반년 넘도록 수사하지 않습니다.
# 2019-12-18
# 493명
# --------------------------------------------------------------------------------
# 229
# 인권/성평등
# 성추행가해자 ***** 이사장 재출마를 막아주세요!!
# 2019-12-18
# 1,124명
# --------------------------------------------------------------------------------
# 228
# 경제민주화
# **그룹의 낯뜨거운 두 얼굴
# 2019-12-18
# 399명
# --------------------------------------------------------------------------------
# 227
# 문화/예술/체육/언론
# KBL프로농구 심판의 자질없는 자들의 승부조작 의심 경기 그들을 조사해주세요
# 2019-12-18
# 469명
# --------------------------------------------------------------------------------
# 226
# 문화/예술/체육/언론
# MBC **** ****년 **월 **일 방송된 "** *** *** **"의 주인공, 정** 감독을 처벌해주세요. 또 다른 피해를 꼭 막아주세요
# 2019-12-18
# 2,584명
# --------------------------------------------------------------------------------
# 225
# 인권/성평등
# 남자 성기를 본떠 만든 여성자위기구 판매를 수입 및 판매를 금지시켜주세요.
# 2019-12-18
# 504명
# --------------------------------------------------------------------------------
# 224
# 인권/성평등
# 게임 업계 일러스트레이터/웹툰 작가 페미니스트 사상검증 블랙리스트” 피해 복구를 바랍니다.
# 2019-12-18
# 14,851명
# --------------------------------------------------------------------------------
# 193
# 인권/성평등
# 매제의 억울한 죽음을 풀어주십시요.
# 2019-12-14
# 5,093명
# --------------------------------------------------------------------------------
# 192
# 행정
# 황당한 음주운전 교통사고의 행정처분 요구와 무차별 폭행으로 인한 강력한 법의 처벌을 원합니다.
# 2019-12-14
# 235명
# --------------------------------------------------------------------------------
# 191
# 교통/건축/국토
# 51억원에 도로 매입하라며 진출입로 폐쇄 논란으로 청원요청드립니다.
# 2019-12-14
# 591명
# --------------------------------------------------------------------------------
# 190
# 안전/환경
# 단역배우 제 2차가해자 경찰을 처벌해 주세요
# 2019-12-14
# 34,790명
# --------------------------------------------------------------------------------
# 189
# 행정
# 대구 북구의 옛 경북도청 터에 시신청사 건립을 반대합니다.
# 2019-12-14
# 294명
# --------------------------------------------------------------------------------
# 188
# 인권/성평등
# 남학교의 명칭도 남자중학교, 남자고등학교로 바꿀 것을 요구합니다
# 2019-12-14
# 5,689명
# --------------------------------------------------------------------------------
# 187
# 기타
# 정준영 / 최종훈 검찰 구형 너무 약합니다 엄중처벌 요구합니다
# 2019-12-14
# 954명
# --------------------------------------------------------------------------------
# 186
# 육아/교육
# 교원임용 답안 및 채점기준 공개 법안 개정 요구합니다.
# 2019-12-14
# 2,564명
# --------------------------------------------------------------------------------
# 185
# 외교/통일/국방
# 해병대 00부대에서 법령을 위반한 의혹이 있어 대통령님께 청원 드립니다.
# 2019-12-14
# 227명
# --------------------------------------------------------------------------------
# 184
# 보건복지
# 화장품에 표기된 제조원 정보 삭제 요청을 막아주십시오
# 2019-12-14
# 755명
# --------------------------------------------------------------------------------
# 183
# 기타
# 협박, 감금, 폭행 무혐의 판결 수사가 너무억울합니다.
# 2019-12-14
# 260명
# --------------------------------------------------------------------------------
# 182
# 외교/통일/국방
# 학교에서 평화통일교육을 배우고 싶습니다.
# 2019-12-14
# 198명
# --------------------------------------------------------------------------------
# 181
# 미래
# 동성혼 법제화를 해 주세요.
# 2019-12-13
# 318명
# --------------------------------------------------------------------------------
# 180
# 문화/예술/체육/언론
# ****과 ***의 해체를 반대합니다.
# 2019-12-13
# 243명
# --------------------------------------------------------------------------------
# 179
# 육아/교육
# 신생아실에 내아이를 언제든 지켜볼수있게 해주세요
# 2019-12-13
# 1,366명
# --------------------------------------------------------------------------------
# 148
# 정치개혁
# 새로운 유능한 검찰총장을 교체해주세요
# 2019-12-11
# 2,834명
# --------------------------------------------------------------------------------
# 147
# 외교/통일/국방
# 홍콩 시위와 관련하여 입장을 표명하고 대한민국의 언론 자유를 무시하는 중국인들을 추방해 주세요!
# 2019-12-11
# 640명
# --------------------------------------------------------------------------------
# 146
# 육아/교육
# 공주 한일고등학교에 제발 교육부 장관님 방문해 주세요.
# 2019-12-11
# 1,064명
# --------------------------------------------------------------------------------
# 145
# 기타
# ㈜***투어의 김ㅇㅇ실장 법정구속 수사를 원합니다.
# 2019-12-11
# 458명
# --------------------------------------------------------------------------------
# 144
# 육아/교육
# 다자녀가구에 실질적인 지원을 부탁드립니다.
# 2019-12-11
# 630명
# --------------------------------------------------------------------------------
# 143
# 외교/통일/국방
# ■ BTS,이강인 (방탄소년단)비롯-군복무 특수 연기제도 신설요청!(면제요청 아님)
# 2019-12-11
# 330명
# --------------------------------------------------------------------------------
# 142
# 기타
# **경찰서 신OO경찰관의 처벌을 원합니다.
# 2019-12-11
# 364명
# --------------------------------------------------------------------------------
# 141
# 기타
# 국토부 장관 교체해주세요.
# 2019-12-11
# 808명
# --------------------------------------------------------------------------------
# 140
# 인권/성평등
# 군복무 중 억울하게 신체에 장애를 얻었습니다.
# 2019-12-11
# 1,851명
# --------------------------------------------------------------------------------
# 139
# 문화/예술/체육/언론
# 청각장애인용 한글 자막 제작을 의무화할 것을 청원합니다.
# 2019-12-11
# 200명
# --------------------------------------------------------------------------------
# 138
# 기타
# 피해자가 가해자가 되었는데 법제도의 현실에 또한번 좌절합니다.
# 2019-12-11
# 420명
# --------------------------------------------------------------------------------
# 137
# 교통/건축/국토
# 용서고속도로 삼거리에서 차와 오토바이가 뺑소니를 당했 습니다
# 2019-12-11
# 177명
# --------------------------------------------------------------------------------
# 136
# 안전/환경
# 어린이들의 생명안전법안 통과를 촉구해주시길 간곡히 부탁드립니다
# 2019-12-11
# 408,053명
# --------------------------------------------------------------------------------
# 135
# 경제민주화
# 금융위원회 해체하고 금융감독원은 공공기관으로 지정하라.
# 2019-12-11
# 1,373명
# --------------------------------------------------------------------------------
# 134
# 문화/예술/체육/언론
# ****과 *** 해체를 반대합니다
# 2019-12-11
# 462명
# --------------------------------------------------------------------------------
# 118
# 정치개혁
# 민노총 폐지 동의하시길 부탁드립니다
# 2019-12-11
# 1,905명
# --------------------------------------------------------------------------------
# 117
# 행정
# 사치성 품목에 부과하는 자동차 개별소비세 인하정책 유지 또는 폐지를 청원드립니다!!!
# 2019-12-11
# 830명
# --------------------------------------------------------------------------------
# 116
# 안전/환경
# 일상생활 속 쓰레기 문제를 줄일 수 있는 정책을 가져와보았습니다.
# 2019-12-11
# 164명
# --------------------------------------------------------------------------------
# 115
# 문화/예술/체육/언론
# 일본에 잠들어 있는 ‘백제의 미소’ 돌려받자
# 2019-12-11
# 5,202명
# --------------------------------------------------------------------------------
# 114
# 행정
# 공정한 심사를 하지 않고 직무유기하는 보훈처를 고발합니다.
# 2019-12-11
# 149명
# --------------------------------------------------------------------------------
# 113
# 인권/성평등
# **교대 성범죄자들로부터 초등학생들을 지켜주세요.
# 2019-12-11
# 6,573명
# --------------------------------------------------------------------------------
# 112
# 행정
# 강동구 천호4촉진구역 관련 청와대에 청원
# 2019-12-11
# 111명
# --------------------------------------------------------------------------------
# 111
# 문화/예술/체육/언론
# 홍**을 돌려주세요.
# 2019-12-11
# 1,034명
# --------------------------------------------------------------------------------
# 110
# 경제민주화
# 엄청난 규모의 온라인 중고시장, 엄청난 수의 피해자들을 위한 법개정을 해 주세요!
# 2019-12-11
# 279명
# --------------------------------------------------------------------------------
# 109
# 인권/성평등
# 핑크택스 철폐를 청원합니다.
# 2019-12-11
# 10,777명
# --------------------------------------------------------------------------------
# 108
# 기타
# 소년범죄에 대한 심각성과 그에 따른 종합적인해결방안을 건의합니다
# 2019-12-11
# 238명
# --------------------------------------------------------------------------------
# 107
# 문화/예술/체육/언론
# 엠@ 서바이벌 아이돌 프로그램 프@@스PD 안**PD를 처벌해주세요
# 2019-12-11
# 305명
# --------------------------------------------------------------------------------
# 106
# 안전/환경
# 대통령 님, 제발 제 얘기 좀 들어 주세요.
# 2019-12-11
# 566명
# --------------------------------------------------------------------------------
# 105
# 경제민주화
# *****의 범죄행위 고발
# 2019-12-11
# 286명
# --------------------------------------------------------------------------------
# 104
# 육아/교육
# 외고, 자사고, 국제고 폐지를 철회해 주세요
# 2019-12-11
# 17,491명
# --------------------------------------------------------------------------------
# 103
# 기타
# 교통사고 관련 보상에 대해 국민청원의 글을 올립니다.
# 2019-12-11
# 134명
# --------------------------------------------------------------------------------
# 102
# 육아/교육
# 장애아동 도움반 모든 학교에 의무로 해 주세요
# 2019-12-11
# 616명
# --------------------------------------------------------------------------------
# 101
# 인권/성평등
# 아이돌을 비방하는 악플을 이제 멈춰주세요
# 2019-12-11
# 243명
# --------------------------------------------------------------------------------
# 100
# 문화/예술/체육/언론
# ***과 ****의 해체를 반대합니다!
# 2019-12-08
# 1,849명
# --------------------------------------------------------------------------------
# 99
# 안전/환경
# 아파트 건설현장에서 억울하고 비참하게 사망한 저의 아버지 원한을 풀어주시고 건설사(**건설(주)갑질,횡포)를 고발합니다.
# 2019-12-08
# 3,804명
# --------------------------------------------------------------------------------
# 98
# 육아/교육
# [생후 25일] ‘심장 판막도 제대로 형성되지 못하고 태어난 **...’ 정부지원 산후도우미로부터 20여일 가까이 지옥 같은 고통을 받아 죽을 뻔한 **를 제발 도와주세요...
# 2019-12-08
# 18,177명
# --------------------------------------------------------------------------------
# 97
# 기타
# 인천 ** 경찰서 *****과 **팀의 불공정 수사 및 편파 수사 행태를  징계하여 재수사가 이루어지게 도와 주십시요!!
# 2019-12-08
# 3,150명
# --------------------------------------------------------------------------------
# 96
# 안전/환경
# 상수원 다변화 공약을 실천해 주세요.
# 2019-12-08
# 470명
# --------------------------------------------------------------------------------
# 95
# 외교/통일/국방
# 조현천 전 기무사령관의 연금지급 중지를 요청합니다.
# 2019-12-08
# 16,080명
# --------------------------------------------------------------------------------
# 94
# 일자리
# 외교센터 근무 용역직원 강제 해고하지 말고 고용승계를 해주세요
# 2019-12-08
# 185명
# --------------------------------------------------------------------------------
# 93
# 문화/예술/체육/언론
# **** 논란
# 2019-12-08
# 350명
# --------------------------------------------------------------------------------
# 92
# 인권/성평등
# **** 이슈에 대한  온라인상 과격한 댓글 경찰 감시 및 수사요청
# 2019-12-08
# 446명
# --------------------------------------------------------------------------------
# 91
# 문화/예술/체육/언론
# *** 과 **** 의 지상파 출연을 가능하게 해주세요.
# 2019-12-08
# 6,857명
# --------------------------------------------------------------------------------
# 90
# 경제민주화
# 무차입 공매도에 엄벌을 내려주세요
# 2019-12-08
# 2,491명
# --------------------------------------------------------------------------------
# 89
# 교통/건축/국토
# 미끄럼방지 도로 사고다발구역
# 2019-12-08
# 160명
# --------------------------------------------------------------------------------
# 58
# 행정
# ****** . *****.  등  기업사냥꾼 종목을 조사해주세요
# 2019-12-06
# 481명
# --------------------------------------------------------------------------------
# 57
# 기타
# ** 광고비 부당 청구 환불 요구의 건
# 2019-12-06
# 351명
# --------------------------------------------------------------------------------
# 56
# 안전/환경
# 층간소음
# 2019-12-06
# 516명
# --------------------------------------------------------------------------------
# 55
# 인권/성평등
# 소년법 폐지
# 2019-12-06
# 735명
# --------------------------------------------------------------------------------
# 54
# 교통/건축/국토
# 선사시대 유적지 위에 짓는 레고랜드 사업을 중단해주세요
# 2019-12-06
# 2,264명
# --------------------------------------------------------------------------------
# 53
# 문화/예술/체육/언론
# 공영방송 EBS의 수신료를 늘려주세요
# 2019-12-06
# 5,555명
# --------------------------------------------------------------------------------
# 52
# 교통/건축/국토
# 경기도 광주시의 베드타운화를 막아 주세요.
# 2019-12-06
# 2,191명
# --------------------------------------------------------------------------------
# 51
# 교통/건축/국토
# 청량리역 분당선 증차 조속한 시행을 촉구합니다
# 2019-12-06
# 1,833명
# --------------------------------------------------------------------------------
# 50
# 교통/건축/국토
# 분당선 - 경춘선 직결화 빠른 시행 촉구합니다
# 2019-12-06
# 4,115명
# --------------------------------------------------------------------------------
# 49
# 교통/건축/국토
# 서부권 광역철도 인천공항-인천서구-인천계양- 부천 대장, 당아래-서울2호선라인-하남 연장을 청원합니다.
# 2019-12-05
# 2,038명
# --------------------------------------------------------------------------------
# 48
# 행정
# 공무원의 허위 수당 부정수령 횡령죄로 처벌해야 합니다.
# 2019-12-05
# 495명
# --------------------------------------------------------------------------------
# 47
# 기타
# 대통령 비하 하는 유투브들 처벌
# 2019-12-05
# 1,474명
# --------------------------------------------------------------------------------
# 46
# 안전/환경
# 보잉737NG 기종에 대한 전체 안전 점검이 마무리되는 시점까지 항공권 무료 취소 가능하도록 해야합니다.
# 2019-12-05
# 468명
# --------------------------------------------------------------------------------
# 45
# 교통/건축/국토
# 선분양제 악용해서 사기분양 수준으로 부실시공하는 *** 건설! 수분양자 권리 보호해주세요.
# 2019-12-05
# 790명
# --------------------------------------------------------------------------------
# 44
# 안전/환경
# 안녕하세요. 저는 올 10월 13일 죽도 해변에서 실종된 실종자의 아내입니다.
# 2019-12-05
# 2,498명
# --------------------------------------------------------------------------------
# 43
# 행정
# 서울시 성북구청의 탁상행정으로 1만명의 주민이 고통받고 있습니다
# 2019-12-05
# 870명
# --------------------------------------------------------------------------------
# 42
# 육아/교육
# 147억원 유치원 비리를 무혐의 처분한, 의정부지검 *** 검사를 파면해야 합니다!
# 2019-12-05
# 2,285명
# --------------------------------------------------------------------------------
# 41
# 기타
# 경기도 성남지멱 폭력조직원 김** 입니다. "파타야 살인사건"
# 2019-12-05
# 170명
# --------------------------------------------------------------------------------
# 40
# 교통/건축/국토
# 전세자들사는 집 압류되도록 세금 체납하는 집주인 다시는부동산거래못하게해주세요
# 2019-12-05
# 408명
# --------------------------------------------------------------------------------
# 39
# 경제민주화
# ***** 종로창신점의 폐업을 도와주세요
# 2019-12-05
# 139명
# --------------------------------------------------------------------------------
# 38
# 육아/교육
# 근로정신대 할머니들에 대해 교과서에 써주세요.
# 2019-12-05
# 562명
# --------------------------------------------------------------------------------
# 37
# 정치개혁
# 네이버 밴드에 불법으로 공유되고 있는 소설 텍본러 처벌 부탁드립니다
# 2019-12-05
# 1,200명
# --------------------------------------------------------------------------------
# 36
# 보건복지
# 아버지의 억울함을 풀어주세요
# 2019-12-05
# 730명
# --------------------------------------------------------------------------------
# 35
# 교통/건축/국토
# 노후경유차 세금인상 계획을 철회하라.
# 2019-12-04
# 3,084명
# --------------------------------------------------------------------------------
# 34
# 행정
# 상식이 통하는 나라를 만든다고 하셨잖아요? 국민연금과 장애인 관련 1탄
# 2019-12-04
# 162명
# --------------------------------------------------------------------------------
# 33
# 인권/성평등
# 구미에서 일어난 미성년자 불법촬영 가해자의 엄중한 처벌을 요구합니다
# 2019-12-04
# 451명
# --------------------------------------------------------------------------------
# 32
# 정치개혁
# 문재인 대통령의 하야를 명령합니다.
# 2019-12-04
# 1,362명
# --------------------------------------------------------------------------------
# 31
# 정치개혁
# 조국 장관 관련 검찰 수사팀 수사해줄것을 요청드립니다.
# 2019-12-04
# 5,638명
# --------------------------------------------------------------------------------
# 30
# 행정
# 친일재산환수 재추진을 위한 친일재산환수 담당 상설기구 구성을 촉구합니다.
# 2019-12-04
# 2,791명
# --------------------------------------------------------------------------------
# 29
# 정치개혁
# 국민들이 궁금해하는 *** 대표 ***에 대해 특검을 요청합니다!
# 2019-12-04
# 3,469명
# --------------------------------------------------------------------------------
# 28
# 교통/건축/국토
# 대구시및 지자체의 무분별 재개발과 졸속 건축 교통심의
# 2019-12-04
# 198명
# --------------------------------------------------------------------------------
# 27
# 문화/예술/체육/언론
# 아이들이 창의적인 교육을 받을 수 있도록 예술강사를 지켜주세요.
# 2019-12-04
# 1,780명
# --------------------------------------------------------------------------------
# 26
# 경제민주화
# 금융당국 부터 조사해야 합니다.
# 2019-12-04
# 13,432명
# --------------------------------------------------------------------------------
# 25
# 문화/예술/체육/언론
# 공영방송을 선거로 정할 수 있게 해주십시오.
# 2019-12-04
# 526명
# --------------------------------------------------------------------------------
# 24
# 인권/성평등
# 조국 전 장관 관련 ****** 상장폐지된다면 국민개미들 다 죽습니다.
# 2019-12-04
# 639명
# --------------------------------------------------------------------------------
# 23
# 경제민주화
# 흑자기업 ****** 상장폐지, 이게 나라입니까?
# 2019-12-04
# 686명
# --------------------------------------------------------------------------------
# 22
# 정치개혁
# 검찰피해자 조사위원회를 설치해 주세요
# 2019-12-04
# 45,068명
# --------------------------------------------------------------------------------
# 21
# 교통/건축/국토
# 닭장같은 아파트 동간거리 9미터 못박은 서울시 갑질행정을 시정해주세요
# 2019-12-04
# 698명
# --------------------------------------------------------------------------------
# 20
# 교통/건축/국토
# 음주운전으로 인한 근로자 사망
# 2019-12-04
# 317명
# --------------------------------------------------------------------------------
# 19
# 인권/성평등
# 공군 **전투비행단 군종실장 ***목사의 갑질 및 권력남용과 인권침해, 사적지시 사례를 고발합니다.
# 2019-12-04
# 434명
# --------------------------------------------------------------------------------
# 18
# 문화/예술/체육/언론
# ****교회 법인허가 취소 해주세요.
# 2019-12-04
# 715명
# --------------------------------------------------------------------------------
# 17
# 기타
# 악덕건물주의 횡포와 사기,몇번의 양도방해로 인해 2년동안 통곡할억울함에 고통을 겪고 있습니다. 끝까지 읽어주시고 제발 도와주세요!!!
# 2019-12-04
# 188명
# --------------------------------------------------------------------------------
# 16
# 정치개혁
# 일산을 제발 살려주세요.
# 2019-12-04
# 671명
# --------------------------------------------------------------------------------
# 15
# 안전/환경
# 남앙주 다산 지금지구 9호선 유치 강력요구합니나
# 2019-12-04
# 4,294명
# --------------------------------------------------------------------------------
# 14
# 교통/건축/국토
# 서울동북부권. 경기북권 고속열차(SRT) 서비스 제공되어야 합니다!!
# 2019-12-04
# 1,456명

# %%
len(df_petition)
# Out:
# 210

# %%
df_petition.head(20)
# Out:
#      번호           분류                                                 제목  \
# 0   463           기타                                 불공정한보도를한 언론의 제재시스템
# 1   462     교통/건축/국토                         부동산 다운계약, 다운거래의 악습을 끊어주세요.
# 2   461        육아/교육    교육부의 지침에 따른 고등학교 윤리교과서의 "인민주권"표기에 대해 수정을 요구합니다.
# 3   460        육아/교육                  성폭력을 두둔한 박능후 보건복지부 장관의 사퇴를 촉구합니다.
# 4   459  문화/예술/체육/언론   성남 어린이집 성폭행 사건 가해자 아버지가 소속된 **** **팀 해산을 요청 합니다.
# 5   458        육아/교육                          사립 유치원 교사들도 국가호봉 지급해 주세요.
# 6   457       인권/성평등                       피해자 중심적인 보도와 법률집행의 폐단을 없애주세요
# 7   456         보건복지       BRCA 유전자 변이가 없는 91%의 난소암 환자들도 신약을 복용하게 해주세요.
# 8   455         정치개혁                            직무유기 국회의원 처벌법 제정을 청원합니다
# 9   454        안전/환경                             업주들만 처벌받는 미성년자의 음주, 흡연
# 10  453        육아/교육               서울 중구청장의 졸속행정으로 부터 중구 아이들을 살려주십시오!!!
# 11  452     교통/건축/국토              은평뉴타운내 주민의견을 무시한 여명학교 신설/이전 추진을 막아주세요
# 12  451        육아/교육                 부모들이 안심하고 자녀를 보낼 수 있는 유치원을 만들어주세요.
# 13  450          일자리                              150여명의 직원이 실직자가 되었습니다
# 14  449        육아/교육  청소년을 착취하며 성장한 1:1 영어 교육업체 ******-에 대한 감사 및 사법조...
# 15  448     교통/건축/국토               부실공사 **건설과 부실을 관가하는 시행사 lh공사를 고발합니다.
# 16  447        육아/교육  고교교사가 제 자녀의 학생부에 악의적 허위내용을 기재하여 수시전형에서 모두 탈락하게...
# 17  446         정치개혁        국회에서는 법안으로 인질 잡고 협상하는 카드로 사용하지 말아 주시기 바랍니다.
# 18  445         정치개혁                              국회의원 임기 제한제 도입을 촉구합니다
# 19  444        육아/교육                               처음학교로 시스템 개선이 필요합니다.
#
#         청원 종료일    참여인원
# 0   2020-01-02    135명
# 1   2020-01-02    105명
# 2   2020-01-02    137명
# 3   2020-01-02  6,291명
# 4   2020-01-02  1,706명
# 5   2020-01-02    114명
# 6   2020-01-02    132명
# 7   2020-01-02    498명
# 8   2020-01-02    340명
# 9   2020-01-02    259명
# 10  2020-01-02    316명
# 11  2020-01-02    116명
# 12  2020-01-02    281명
# 13  2020-01-02    129명
# 14  2020-01-02    125명
# 15  2020-01-02    139명
# 16  2020-01-01    284명
# 17  2020-01-01    301명
# 18  2020-01-01    369명
# 19  2020-01-01    247명

# %%
분류 기타
제목 불공정한보도를한 언론의 제재시스템
청원 종료일 2020-01-02
참여인원 118명
